# %%
# !pip install tfx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.5/173.5 kB 11.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.9/99.9 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/Pengumpulan Tugas/MLOps ML CC Pipeline"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Pengumpulan Tugas/MLOps ML CC Pipeline

# %%
# !python local_pipeline.py
# Out:
# Streaming output truncated to the last 5000 lines.
# writing tfx_user_code_Transform.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Transform.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Transform.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# Copying tfx_user_code_Transform.egg-info to /tmp/tmpjumdg9i_/tfx_user_code_Transform-0.0+4fe788bf9f4443c37c5d62c80801c1d5c850d72fccafb30af37fb99733dc12bf-py3.10.egg-info
# running install_scripts
# creating /tmp/tmpjumdg9i_/tfx_user_code_Transform-0.0+4fe788bf9f4443c37c5d62c80801c1d5c850d72fccafb30af37fb99733dc12bf.dist-info/WHEEL
# creating '/tmp/tmpmth7_6qi/tfx_user_code_Transform-0.0+4fe788bf9f4443c37c5d62c80801c1d5c850d72fccafb30af37fb99733dc12bf-py3-none-any.whl' and adding '/tmp/tmpjumdg9i_' to it
# ...

# %%
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm
